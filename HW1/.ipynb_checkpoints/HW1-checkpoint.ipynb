# %%
import numpy as np
import pandas as pd
from pyquery import PyQuery as pq
import time
import datetime
import requests
import urllib.request
import os
import calendar

# %%
# input
ETF_data = pd.read_csv('Emerging Asia Pacific ETF List (114).csv')

# filter the inception date
ETF_data['Inception'] = pd.to_datetime(ETF_data['Inception'], format="%d/%m/%Y")
date = datetime.datetime(2016, 1, 1, 0, 0)
ETF_data = ETF_data.loc[ETF_data['Inception'] < date,:].reset_index()

# extract symbol and name of each ETF
symbol_list = ETF_data['Symbol']
name_list = ETF_data['ETF Name']

# %%
homepage_list = []
for i in symbol_list:
    url = 'https://www.etf.com/'+i+'#overview'
    res = requests.get(url)
    doc = pq(res.text)
    doc.make_links_absolute(res.url)
    homepage_list.append(doc('.field-content.helplink')('a').attr('href'))

# %%
dic = {'symbol':[],'name':[],'addr':[]}
for i,s in enumerate(symbol_list):
    dic['symbol'].append(s)
    dic['name'].append(name_list[i])
    dic['addr'].append(homepage_list[i])
    print(s,name_list[i],homepage_list[i])
# Out:
# XCEM Columbia EM Core ex-China ETF http://www.columbiathreadneedleetf.com/emergingmarkets/xcem
# INCO Columbia India Consumer ETF http://www.columbiathreadneedleetf.com/emergingmarkets/inco
# INXX Columbia India Infrastructure Index Fund http://www.columbiathreadneedleetf.com/emergingmarkets/inxx
# SCIN Columbia India Small Cap Fund http://www.columbiathreadneedleetf.com/emergingmarkets/scin
# AFTY CSOP FTSE China A50 ETF http://www.csopasset.us/en-us/products/etf/a50/
# CNHX CSOP MSCI China A International Hedged ETF http://www.csopasset.us/en-us/products/etf/csop-msci-china-a-international-hedged-etf/
# YANG Direxion Daily China 3x Bear Shares http://www.direxioninvestments.com/products/direxion-daily-china-bear-3x-etf
# YINN Direxion Daily China 3x Bull Shares http://www.direxioninvestments.com/products/direxion-daily-china-bull-3x-etf
# CHAD Direxion Daily CSI 300 China A Share Bear 1X Shares http://www.direxioninvestments.com/products/direxion-daily-csi-300-china-a-share-bear-1x-shares
# CHAU Direxion Daily CSI 300 China A Share Bull 2x Shares http://www.direxioninvestments.com/products/direxion-daily-csi-300-china-a-share-bull-2x-shares
# EDZ Direxion Daily Emerging Markets Bear 3X Shares http://www.direxionfunds.com/products/direxion-daily-emerging-markets-bear-3x-etf
# EDC Direxion Daily Emerging Markets Bull 3X Shares http://www.direxionfunds.com/products/direxion-daily-emerging-markets-bull-3x-etf
# INDL Direxion Daily India Bull 3x Shares http://www.direxioninvestments.com/products/direxion-daily-india-bull-3x-etf
# EMQQ Emerging Markets Internet & Ecommerce ETF https://emqqetf.com/
# FCA First Trust China AlphaDEX Fund http://www.ftportfolios.com/retail/etf/etfsummary.aspx?Ticker=FCA
# FEM First Trust Emerging Markets AlphaDEX Fund http://www.ftportfolios.com/retail/ETF/ETFsummary.aspx?Ticker=FEM
# FEMS First Trust Emerging Markets Small Cap AlphaDEX Fund http://www.ftportfolios.com/retail/ETF/ETFsummary.aspx?Ticker=FEMS
# NFTY First Trust India NIFTY 50 Equal Weight ETF https://www.ftportfolios.com/Retail/Etf/EtfSummary.aspx?Ticker=NFTY
# FNI First Trust ISE Chindia Index Fund http://www.ftportfolios.com/Retail/Etf/EtfSummary.aspx?Ticker=Fni
# ASEA Global X FTSE ASEAN 40 ETF http://www.globalxfunds.com/ASEA
# CHIC Global X MSCI China Communication Services ETF http://www.globalxfunds.com/CHIC
# CHIQ Global X MSCI China Consumer Discretionary ETF http://www.globalxfunds.com/CHIQ
# CHIE Global X MSCI China Energy ETF http://www.globalxfunds.com/CHIE
# CHIX Global X MSCI China Financials ETF http://www.globalxfunds.com/CHIX
# CHII Global X MSCI China Industrials ETF http://www.globalxfunds.com/CHII
# CHIM Global X MSCI China Materials ETF http://www.globalxfunds.com/CHIM
# ADRE Invesco BLDRS Emerging Markets 50 ADR Index Fund https://www.invesco.com/portal/site/us/investors/etfs/product-detail?productId=ADRE
# YAO Invesco China All-Cap ETF None
# HAO Invesco China Small Cap ETF https://www.invesco.com/portal/site/us/investors/etfs/product-detail?productId=HAO
# CQQQ Invesco China Technology ETF https://www.invesco.com/portal/site/us/investors/etfs/product-detail?productId=CQQQ
# PIE Invesco DWA Emerging Markets Momentum ETF https://www.invesco.com/portal/site/us/financial-professional/etfs/product-detail?productId=pie
# PGJ Invesco Golden Dragon China ETF https://www.invesco.com/portal/site/us/financial-professional/etfs/product-detail?productId=pgj
# PIN Invesco India ETF https://www.invesco.com/portal/site/us/financial-professional/etfs/product-detail?productId=pin
# FXI iShares China Large-Cap ETF https://www.ishares.com/us/products/239536/ishares-china-largecap-etf
# AXJV iShares Edge MSCI Min Vol Asia ex Japan ETF https://www.ishares.com/us/products/264606/ishares-msci-asia-ex-japan-minimum-volatility-etf
# EEMV iShares Edge MSCI Min Vol Emerging Markets ETF http://us.ishares.com/product_info/fund/overview/EEMV.htm
# EMGF iShares Edge MSCI Multifactor Emerging Markets ETF https://www.ishares.com/us/products/272820/EMGF?referrer=tickerSearch
# INDY iShares India 50 ETF https://www.ishares.com/us/products/239758/ishares-india-50-etf
# AAXJ iShares MSCI All Country Asia ex-Japan ETF https://www.ishares.com/us/products/239601/ishares-msci-all-country-asia-ex-japan-etf
# MCHI iShares MSCI China ETF https://www.ishares.com/us/products/239619/ishares-msci-china-etf
# ECNS iShares MSCI China Small-Cap ETF http://us.ishares.com/product_info/fund/overview/ECNS.htm
# EEMA iShares MSCI Emerging Markets Asia ETF http://us.ishares.com/product_info/fund/overview/EEMA.htm
# EEM iShares MSCI Emerging Markets ETF http://us.ishares.com/product_info/fund/overview/EEM.htm
# INDA iShares MSCI India ETF https://www.ishares.com/us/products/239659/ishares-msci-india-etf
# SMIN iShares MSCI India Small-Cap ETF https://www.ishares.com/us/products/239660/SMIN
# EIDO iShares MSCI Indonesia ETF http://us.ishares.com/product_info/fund/overview/EIDO.htm
# EWM iShares MSCI Malaysia ETF http://us.ishares.com/product_info/fund/overview/EWM.htm
# EPHE iShares MSCI Philippines ETF http://us.ishares.com/product_info/fund/overview/EPHE.htm
# THD iShares MSCI Thailand ETF https://www.ishares.com/us/products/239688/THD
# AIA iShares S&P Asia ETF https://www.ishares.com/us/products/239730/ishares-asia-50-etf
# KBA KraneShares Bosera MSCI China A Share ETF http://kraneshares.com/kba/
# KFYP KraneShares CSI China Five Year Plan ETF http://kraneshares.com/kfyp/
# KWEB KraneShares CSI China Internet ETF http://kraneshares.com/kweb/
# KALL KraneShares MSCI China All Shares Index ETF https://kraneshares.com/kall/
# YXI ProShares Short FTSE China 50 http://www.proshares.com/funds/yxi.html
# XPP ProShares Ultra FTSE China 50 http://www.proshares.com/funds/xpp.html
# EET ProShares Ultra MSCI Emerging Markets http://www.proshares.com/funds/eet.html
# FXP ProShares UltraShort China 50 http://www.proshares.com/funds/fxp.html
# EUM Short MSCI Emerging Markets ProShares http://www.proshares.com/funds/eum.html
# XINA SPDR MSCI China A Shares IMI ETF https://us.spdrs.com/en/etf/spdr-msci-china-a-shares-imi-etf-XINA
# SPEM SPDR Portfolio Emerging Markets ETF https://us.spdrs.com/en/etf/spdr-portfolio-emerging-markets-etf-SPEM
# GXC SPDR S&P China ETF https://us.spdrs.com/en/etf/spdr-sp-china-etf-GXC
# GMF SPDR S&P Emerging Asia Pacific ETF https://us.spdrs.com/en/etf/spdr-sp-emerging-asia-pacific-etf-GMF
# EDIV SPDR S&P Emerging Markets Dividend ETF https://us.spdrs.com/en/etf/spdr-sp-emerging-markets-dividend-etf-EDIV
# EWX SPDR S&P Emerging Small Cap ETF https://us.spdrs.com/en/etf/spdr-sp-emerging-markets-small-cap-etf-EWX
# EEV UltraShort MSCI Emerging Markets http://www.proshares.com/funds/eev.html
# PEK VanEck Vectors ChinaAMC CSI 300 ETF http://www.vaneck.com/vaneck-vectors/equity-etfs/pek/snapshot/
# CNXT VanEck Vectors ChinaAMC SME-ChiNext ETF http://www.vaneck.com/vaneck-vectors/equity-etfs/cnxt/snapshot/
# SCIF VanEck Vectors India Small-Cap Index ETF http://www.vaneck.com/vaneck-vectors/equity-etfs/scif/snapshot/
# IDX VanEck Vectors Indonesia Index ETF http://www.vaneck.com/vaneck-vectors/equity-etfs/idx/snapshot/
# VNM VanEck Vectors Vietnam ETF http://www.vaneck.com/vaneck-vectors/equity-etfs/vnm/snapshot/
# VWO Vanguard FTSE Emerging Markets ETF https://personal.vanguard.com/us/funds/snapshot?FundId=0964&FundIntExt=INT
# CXSE WisdomTree China ex-State-Owned Enterprises Fund https://www.wisdomtree.com/etfs/equity/cxse
# DGRE WisdomTree Emerging Markets Dividend Growth Fund https://www.wisdomtree.com/etfs/equity/dgre
# DEM WisdomTree Emerging Markets Equity Income Fund https://www.wisdomtree.com/etfs/equity/dem
# DGS WisdomTree Emerging Markets SmallCap Divdend Fund https://www.wisdomtree.com/etfs/equity/dgs
# EPI WisdomTree India Earnings Fund https://www.wisdomtree.com/etfs/equity/epi
# ASHX Xtrackers CSI 300 China A-Shares Hedged Equity ETF https://dws.com/US/EN/Product-Detail-Page/ASHX
# ASHR Xtrackers Harvest CSI 300 China A-Shares Fund https://dws.com/US/EN/Product-Detail-Page/ASHR
# ASHS Xtrackers Harvest CSI 500 China-A Shares Small Cap Fund https://dws.com/US/EN/Product-Detail-Page/ASHS
# CN Xtrackers Harvest MSCI All China Equity Fund https://dws.com/US/EN/Product-Detail-Page/CN
# DBEM Xtrackers MSCI Emerging Markets Currency-Hedged Equity Fund https://dws.com/US/EN/Product-Detail-Page/DBEM

# %%
def get_the_last_day_of_month(start_date,end_date):
    ans = []
    temp = start_date - datetime.timedelta(1)
    year = start_date.year
    month = start_date.month
    
    while (temp < end_date):
        temp = temp + datetime.timedelta(calendar.monthrange(year,month)[1])
        ans.append(temp)
        month += 1
        if(month > 12):
            month = 1
            year += 1
    return ans

# %%
last_day_of_month = get_the_last_day_of_month(datetime.datetime(2016,1,1,0,0),datetime.datetime(2018,12,31,0,0))

# %%
# Columbia
def get_Columbia_NAV(symbol,addr,start,last_day_of_month):
    
    # check directory
    if not os.path.isdir('./data'):
        os.mkdir('./data')
    if not os.path.isdir('./data/Columbia'):
        os.mkdir('./data/Columbia')
    
    # crawl    
    if start:
        res = requests.get(addr)
        doc = pq(res.text)
        doc.make_links_absolute(res.url)
        filename = doc('#fundliterature .link-list')('li:nth-child(6)')('a').attr('href')
        filename = filename.replace(' ','%20')
        urllib.request.urlretrieve(filename, "./data/Columbia/columbia.xls")
        print('Download columbia.xls')
        
        # filter the last of the month
        data = pd.read_excel('./data/Columbia/columbia.xls')
        data = data.rename(columns = data.iloc[2]).iloc[3:,:]
        data['Date'] = pd.to_datetime(data['Date'], format="%Y/%m/%d")
        
        mask = [False for i in range(data['Date'].shape[0])]
        for day in last_day_of_month:
            temp = data['Date'] == day
            mask |= temp
        data = data[mask]
        data.to_excel('./data/Columbia/columbia_filter_day.xls')
    
    # get NAV of each symbol from Columbia
    
    data_filter = pd.read_excel('./data/Columbia/columbia_filter_day.xls')
    data_filter = data_filter[data_filter['Fund Symbol'] == symbol]

    data_symbol = pd.DataFrame(last_day_of_month[::-1],columns=['Date'])
    data_symbol = data_symbol.merge(data_filter[['Date','NAV']],on='Date',how='left')
    data_symbol.to_excel(f'./data/Columbia/{symbol}.xls')

# %%
get_Columbia_NAV(dic['symbol'][0],dic['addr'][0],False,last_day_of_month)
