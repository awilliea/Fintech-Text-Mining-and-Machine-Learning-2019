# %%
import numpy as np
import pandas as pd

# %%
pd_data = pd.read_csv("opaque.csv")
pd_data #ticker, financial season,
# Out:
#           gvkey    datadate  fyearq  fqtr indfmt consol popsrc datafmt    tic  \
# 0          1004  1993/02/28    1992     3   INDL      C      D     STD    AIR
# 1          1004  1993/05/31    1992     4   INDL      C      D     STD    AIR
# 2          1004  1993/08/31    1993     1   INDL      C      D     STD    AIR
# 3          1004  1993/11/30    1993     2   INDL      C      D     STD    AIR
# 4          1004  1994/02/28    1993     3   INDL      C      D     STD    AIR
# 5          1004  1994/05/31    1993     4   INDL      C      D     STD    AIR
# 6          1004  1994/08/31    1994     1   INDL      C      D     STD    AIR
# 7          1004  1994/11/30    1994     2   INDL      C      D     STD    AIR
# 8          1004  1995/02/28    1994     3   INDL      C      D     STD    AIR
# 9          1004  1995/05/31    1994     4   INDL      C      D     STD    AIR
# 10         1004  1995/08/31    1995     1   INDL      C      D     STD    AIR
# ...
